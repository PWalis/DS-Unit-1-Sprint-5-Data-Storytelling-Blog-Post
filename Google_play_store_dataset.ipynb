# %% [markdown]
# <a href="https://colab.research.google.com/github/PWalis/DS-Unit-1-Sprint-5-Data-Storytelling-Blog-Post/blob/master/Google_play_store_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

apps = pd.read_csv('https://raw.githubusercontent.com/PWalis/Datasets/master/googleplaystore.csv?token=AuLu2XxjqENyb4Mf7TZb77rWX-0DWoodks5cvik5wA%3D%3D')
reviews = pd.read_csv('https://raw.githubusercontent.com/PWalis/Datasets/master/googleplaystore_user_reviews.csv?token=AuLu2foDBD38EOA2WXxH0Xz8hU7wiBX3ks5cvil3wA%3D%3D')

# %%
pd.set_option('display.max_columns', 500)

# %%
reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
apps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
for column in apps.columns:
  print(apps[column].value_counts(),'\n#####################################################\n')
# Out:
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# ESPN                                                  7
# Duolingo: Learn Languages Free                        7
# 8 Ball Pool                                           7
# Candy Crush Saga                                      7
# Temple Run 2                                          6
# slither.io                                            6
# Subway Surfers                                        6
# Zombie Catchers                                       6
# Nick                                                  6
# Bowmasters                                            6
# Bubble Shooter                                        6
# Helix Jump                                            6
# Sniper 3D Gun Shooter: Free Shooting Games - FPS      6
# Bleacher Report: sports news, scores, & highlights    6
# Skyscanner                                            5
# ...

# %%
for column in reviews.columns:
  print(reviews[column].value_counts(),'\n#####################################################\n')
# Out:
# Bowmasters                                            320
# Angry Birds Classic                                   320
# CBS Sports App - Scores, News, Stats & Watch Live     320
# 8 Ball Pool                                           300
# Helix Jump                                            300
# Calorie Counter - MyFitnessPal                        260
# Bubble Shooter                                        260
# Candy Crush Saga                                      240
# ESPN                                                  240
# DEAD TARGET: FPS Zombie Apocalypse Survival Games     240
# Duolingo: Learn Languages Free                        240
# Garena Free Fire                                      240
# Hangouts                                              220
# Farm Heroes Saga                                      220
# Granny                                                220
# Flow Free                                             220
# ...

# %% [markdown]
# #Taughts/Questions
#  - How do I get rid of the nans without influencing the data all too much and how to do I check how much i've influenced the data?
#  - What should I do about the languages that aren't English
#   - probably just get rid of them
#  - I need to look at the documentation that can wth the data
#  - What does the sentiment subjectivity in the reviews csv mean
#  - I'll need to put unknown for the android version. If the data is missing it probably wasnt on the app store either wich could indicate a poorly made app..... possibly
#  -

# %%
for column in apps.columns:
  print(apps[column].isnull().sum())

apps.columns.tolist()
# Out:
# 0
# 0
# 1474
# 0
# 0
# 0
# 1
# 0
# 1
# 0
# 0
# 8
# 3
# ['App',
#  'Category',
#  'Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
# df = apps.fillna(method ='ffill')

# %%
df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You    This help eating healthy exercise regular basis
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
for column in df.columns:
  print(df[column].isnull().sum())
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
import numpy as np
apps[apps.isnull().any(axis=1)]
# Out:
#                                                      App             Category  \
# 15                       Learn To Draw Kawaii Characters       ART_AND_DESIGN
# 23                                Mcqueen Coloring pages       ART_AND_DESIGN
# 113                            Wrinkles and rejuvenation               BEAUTY
# 123                               Manicure - nail design               BEAUTY
# 126                         Skin Care and Natural Beauty               BEAUTY
# 129                  Secrets of beauty, youth and health               BEAUTY
# 130                   Recipes and tips for losing weight               BEAUTY
# 134                        Lady adviser (beauty, health)               BEAUTY
# 163                           Anonymous caller detection  BOOKS_AND_REFERENCE
# 180                  SH-02J Owner's Manual (Android 8.0)  BOOKS_AND_REFERENCE
# 185                       URBANO V 02 instruction manual  BOOKS_AND_REFERENCE
# ...

# %%
print(apps.columns, apps.shape)
print(reviews.columns, reviews.shape)
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object') (10841, 13)
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object') (64295, 5)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(apps.Rating);
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 100000)

# %%
apps.Price = apps.Price.astype(str)

# %%
temp = apps.Price.str.replace('$', '', regex=False)

# %%
temp.astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-2b7e46c99885> in <module>()
# ----> 1 temp.astype('float')
#
# /usr/local/lib/python3.6/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ...
